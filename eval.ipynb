# %% [markdown]
# ## Import libraries, define model to evaluate. Configuration here
#
# This is a notebook to help you quickly validate your trained models, visualize model output for sanity checking, and saving results for display in README later.

# %%
import numpy as np
import tensorflow as tf
import cv2
import os, datetime, yaml, random, math
from pprint import pprint
from PIL import Image, ImageTk
import matplotlib.pyplot as plt
# %matplotlib inline

MODEL_PATH = "ros/src/tl_detector/models/"

# TODO: add new model here
SSD_CLASSIFIER_COCO = 'ssd_classifier'
SSD_CLASSIFIER_SIM = 'ssd_classifier_sim'
YOLO_TINY_UDACITY = 'yolo_tiny_udacity'

MODEL = {
    SSD_CLASSIFIER_COCO : 'ssd_inception_v2_coco_retrained_sim/frozen_inference_graph.pb',
    SSD_CLASSIFIER_SIM: 'ssd-sim.pb',
}

# TODO: choose your model
CHOSEN_MODEL = SSD_CLASSIFIER_SIM

## YAML files
VALIDATION_YAML_REAL_CONFIG = 'data/validation/real_training_data/real_data_annotations.yaml'
VALIDATION_YAML_SIM_CONFIG = 'data/validation/sim_training_data/sim_data_annotations.yaml'

# TODO: set simulator or real data
IS_SIM = True
if IS_SIM:
    CHOSEN_CONFIG = VALIDATION_YAML_SIM_CONFIG
    BASE_PATH = 'data/validation/sim_training_data/'
else:
    CHOSEN_CONFIG = VALIDATION_YAML_REAL_CONFIG
    BASE_PATH = 'data/validation/real_training_data/'

config = None
with open(CHOSEN_CONFIG) as f:
    config = yaml.safe_load(f)

    
# Set number of files to visualize
NUM_TO_VISUALIZE = 12


# Constants
IMAGE_WIDTH = 800
IMAGE_HEIGHT = 600

# %%
# Helpers
def load_graph(graph_file):
    """Loads a frozen inference graph"""
    graph = tf.Graph()
    with graph.as_default():
        od_graph_def = tf.GraphDef()
        with tf.gfile.GFile(graph_file, 'rb') as fid:
            serialized_graph = fid.read()
            od_graph_def.ParseFromString(serialized_graph)
            tf.import_graph_def(od_graph_def, name='')
    return graph

def class_to_label(predicted_cls):
    if predicted_cls == 1:
        return 'green'
    elif predicted_cls == 2:
        return 'red'
    elif predicted_cls == 3:
        return 'yellow'
    else:
        return 'unknown'

# Helper function to plot graphs and figures
def plot_figures(figures, figSize, r = 1, c=1, labels=None):
    fig, axs = plt.subplots(ncols=c, nrows=r, figsize=figSize)
    axs = axs.ravel()
    for index, title in zip(range(len(figures)), figures):
        axs[index].imshow(figures[title])
        if(labels != None):
            axs[index].set_title(labels[index])
        else:
            axs[index].set_title(title)
            
        axs[index].set_axis_off()
    plt.tight_layout()
    
def bgr_to_rgb(bgr_img):
    b,g,r = cv2.split(bgr_img)       # get b,g,r
    rgb_img = cv2.merge([r,g,b])     # switch it to rgb
    return rgb_img

def get_class_from_config(config_item):
    if (len(config_item['annotations']) == 0):
        return 'Nothing'
    first_annotation = config_item['annotations'][0]
    return first_annotation['class']

def draw_bb_box(image, annotation):
    """
        Draws a bounding box around detections
        Modifies original image
        Expects annnotation to be a dict like this:
        {
            class: Red, 
            x_width: 70.07999999999993, 
            xmin: 695.6800000000001, 
            y_height: 154.88,
            ymin: 194.24
        }
    """
    x = int(annotation['xmin'])
    y = int(annotation['ymin'])
    w = int(annotation['x_width'])
    h = int(annotation['y_height'])
    color = (255,255,255) # default white
    if annotation['class'].lower() == 'red':
        color = (255, 0, 0)
    elif annotation['class'].lower() == 'yellow':
        color = (255, 255, 0)
    elif annotation['class'].lower() == 'green':
        color = (0, 255, 255)
    else:
        pass
    cv2.rectangle(image, (x, y), (x+w, y+h), color, 4)
    
def draw_bb_boxes(image, annotations):
    for a in annotations:
        draw_bb_box(image, a)
        
def to_image_coords(boxes, height, width):
    """
    The original box coordinate output is normalized, i.e [0, 1].
    
    This converts it back to the original coordinate based on the image
    size.
    """
    box_coords = np.zeros_like(boxes)
    box_coords[:, 0] = boxes[:, 0] * height
    box_coords[:, 1] = boxes[:, 1] * width
    box_coords[:, 2] = boxes[:, 2] * height
    box_coords[:, 3] = boxes[:, 3] * width
    
    return box_coords

# %%
# Visualize the images before detection

random.shuffle(config)
config_items = [x for x in config[:NUM_TO_VISUALIZE]]
files_to_load = [x['filename'] for x in config_items]

labels = []
vimages = {}
for i in range(0, NUM_TO_VISUALIZE):
    filepath = os.path.join(BASE_PATH, files_to_load[i])
    labels.append(get_class_from_config(config_items[i]))
    original_img = bgr_to_rgb(cv2.imread(filepath, 1))
    draw_bb_boxes(original_img, config_items[i]['annotations'])
    vimages[i] = original_img
    
plot_figures(vimages, (16,20), 4, 3, labels)
plt.savefig("./report/visualization")

# %%
# Visualize the images after detection

def classify(sess, graph, image, image_tensor, boxes, scores, classes, num_detections):
    """ 
        Now: returns (classID, label, score) of highest scoring prediction
        TODO: returns list of annotation object
    """
    with graph.as_default():
        img_expand = np.expand_dims(image, axis=0)
        start = datetime.datetime.now()
        (boxes, scores, classes, num_detections) = sess.run(
            [boxes, scores, classes, num_detections],
            feed_dict={image_tensor: img_expand})
        end = datetime.datetime.now()
        c = end - start

    boxes = np.squeeze(boxes)
    boxes = to_image_coords(boxes, IMAGE_HEIGHT, IMAGE_WIDTH)
    scores = np.squeeze(scores)
    classes = np.squeeze(classes).astype(np.int32)

    print('Time: %.4f, SCORES: %.6f, CLASSES: %s' % (c.total_seconds(), scores[0], class_to_label(classes[0])))
    annotations = []
    for (score, cls, box) in zip(scores, classes, boxes):
        if score > 0.9: # Can be tweaked
            annotation = {}
            box_width = abs(box[1] - box[3])
            box_height = abs(box[0] - box[2])
            annotation['xmin'] = box[1]
            annotation['ymin'] = box[0]
            annotation['class'] = class_to_label(cls)
            annotation['x_width'] = box_width
            annotation['y_height'] = box_height
            annotation['score'] = score
            annotations.append(annotation)

    if scores[0] > 0.9:
        if classes[0] == 1:
            return (1, 'GREEN', scores[0], annotations)
        elif classes[0] == 2:
            return (2, 'RED', scores[0], annotations)
        elif classes[0] == 3:
            return (3, 'YELLOW', scores[0], annotations)
    return (4, 'UNKNOWN', scores[0], annotations)

graph = tf.Graph()
threshold = 0.5

image_tensor = None
boxes = None
scores = None
classes = None

graph = load_graph(MODEL_PATH + MODEL[CHOSEN_MODEL])
image_tensor = graph.get_tensor_by_name('image_tensor:0')
boxes = graph.get_tensor_by_name('detection_boxes:0')
scores = graph.get_tensor_by_name('detection_scores:0')
classes = graph.get_tensor_by_name('detection_classes:0')
num_detections = graph.get_tensor_by_name('num_detections:0')

sess = tf.Session(graph=graph)

labels = []
labeledImgs = {}
for i in range(0, NUM_TO_VISUALIZE):
    filepath = os.path.join(BASE_PATH, files_to_load[i])
    img = Image.open(filepath)
    numpyImg = np.asarray(img)
    result = classify(sess, graph, img, image_tensor, boxes, scores, classes, num_detections)
    draw_bb_boxes(numpyImg, result[-1])
    labeledImgs[i] = numpyImg
    labels.append(result[:-1])
plot_figures(labeledImgs, (16,20), 4, 3, labels)
plt.savefig('./report/%s_results' % (CHOSEN_MODEL,))
# Out:
# Time: 1.8312, SCORES: 0.938915, CLASSES: yellow
# Time: 0.5941, SCORES: 0.998351, CLASSES: red
# Time: 0.3664, SCORES: 0.909639, CLASSES: red
# Time: 0.5110, SCORES: 0.147913, CLASSES: green
# Time: 0.5665, SCORES: 0.999001, CLASSES: red
# Time: 0.3598, SCORES: 0.850795, CLASSES: yellow
# Time: 0.3799, SCORES: 0.997443, CLASSES: red
# Time: 0.5304, SCORES: 0.503203, CLASSES: red
# Time: 0.5229, SCORES: 0.998472, CLASSES: red
# Time: 0.3466, SCORES: 0.999514, CLASSES: red
# Time: 0.3483, SCORES: 0.996859, CLASSES: green
# Time: 0.3978, SCORES: 0.259895, CLASSES: red

# %%
# Run full evaluation
random.shuffle(config)
config_items = [x for x in config]
files_to_load = [x['filename'] for x in config_items]

acc = 0
total_count = 0
for i in range(0, len(files_to_load)):
    filepath = os.path.join(BASE_PATH, files_to_load[i])
    img = Image.open(filepath)
    ground_truth = get_class_from_config(config_items[i])
    cls, clsLabel, score, bboxes = classify(sess, graph, img, image_tensor, boxes, scores, classes, num_detections)
    total_count += 1
    if clsLabel.lower() == ground_truth.lower():
        acc += 1
print("Total Validation Images : %d, Num correct: %d, Accuracy score: %.3f" % (total_count, acc, acc*1.0/total_count))
# Out:
# Time: 0.4225, SCORES: 0.990522, CLASSES: red
# Time: 0.5086, SCORES: 0.995998, CLASSES: red
# Time: 0.5346, SCORES: 0.956262, CLASSES: yellow
# Time: 0.5460, SCORES: 0.997494, CLASSES: red
# Time: 0.4346, SCORES: 0.991652, CLASSES: red
# Time: 0.5980, SCORES: 0.982834, CLASSES: red
# Time: 0.3582, SCORES: 0.173365, CLASSES: red
# Time: 0.3463, SCORES: 0.997192, CLASSES: green
# Time: 0.4588, SCORES: 0.447100, CLASSES: red
# Time: 0.3406, SCORES: 0.986152, CLASSES: red
# Time: 0.3638, SCORES: 0.997499, CLASSES: green
# Time: 0.3586, SCORES: 0.998035, CLASSES: red
# Time: 0.3566, SCORES: 0.999849, CLASSES: red
# Time: 0.3872, SCORES: 0.995676, CLASSES: red
# Time: 0.4804, SCORES: 0.998278, CLASSES: green
# Time: 0.3920, SCORES: 0.997643, CLASSES: red
# Time: 0.3786, SCORES: 0.991281, CLASSES: red
# Time: 0.4441, SCORES: 0.992897, CLASSES: red
# Time: 0.3604, SCORES: 0.990269, CLASSES: red
# Time: 0.4577, SCORES: 0.979874, CLASSES: red
# Time: 0.3402, SCORES: 0.999395, CLASSES: red
# Time: 0.3460, SCORES: 0.999039, CLASSES: red
# Time: 0.3401, SCORES: 0.015225, CLASSES: yellow
# Time: 0.3971, SCORES: 0.996240, CLASSES: yellow
# Time: 0.3479, SCORES: 0.977169, CLASSES: yellow
# Time: 0.3761, SCORES: 0.989520, CLASSES: red
# Time: 0.3741, SCORES: 0.999586, CLASSES: red
# Time: 0.3949, SCORES: 0.995914, CLASSES: red
# Time: 0.4039, SCORES: 0.934760, CLASSES: red
# Time: 0.4278, SCORES: 0.999090, CLASSES: red
# Time: 0.3688, SCORES: 0.997110, CLASSES: red
# Time: 0.3518, SCORES: 0.307422, CLASSES: red
# Time: 0.3779, SCORES: 0.986920, CLASSES: red
# Time: 0.3588, SCORES: 0.996242, CLASSES: red
# Time: 0.3511, SCORES: 0.991332, CLASSES: yellow
# Time: 0.3540, SCORES: 0.661113, CLASSES: red
# Time: 0.3548, SCORES: 0.995079, CLASSES: green
# Time: 0.3467, SCORES: 0.997126, CLASSES: green
# Time: 0.4031, SCORES: 0.993307, CLASSES: red
# Time: 0.3741, SCORES: 0.999636, CLASSES: red
# Time: 0.4495, SCORES: 0.999821, CLASSES: red
# Time: 0.3647, SCORES: 0.948584, CLASSES: yellow
# Time: 0.3856, SCORES: 0.996268, CLASSES: red
# Time: 0.3718, SCORES: 0.999672, CLASSES: red
# Time: 0.4450, SCORES: 0.992411, CLASSES: red
# Time: 0.3612, SCORES: 0.909639, CLASSES: red
# Time: 0.3463, SCORES: 0.766655, CLASSES: red
# Time: 0.3756, SCORES: 0.994350, CLASSES: red
# Time: 0.3448, SCORES: 0.980568, CLASSES: yellow
# Time: 0.3460, SCORES: 0.998351, CLASSES: red
# Time: 0.3597, SCORES: 0.377277, CLASSES: red
# Time: 0.3705, SCORES: 0.056501, CLASSES: green
# Time: 0.3972, SCORES: 0.989771, CLASSES: red
# Time: 0.4611, SCORES: 0.999780, CLASSES: red
# Time: 0.3832, SCORES: 0.997192, CLASSES: green
# Time: 0.3979, SCORES: 0.095898, CLASSES: yellow
# Time: 0.3496, SCORES: 0.998637, CLASSES: red
# Time: 0.3631, SCORES: 0.994173, CLASSES: red
# Time: 0.3513, SCORES: 0.999403, CLASSES: red
# Time: 0.3556, SCORES: 0.990447, CLASSES: yellow
# Time: 0.3441, SCORES: 0.994407, CLASSES: red
# Time: 0.3827, SCORES: 0.059505, CLASSES: yellow
# Time: 0.3514, SCORES: 0.074704, CLASSES: yellow
# Time: 0.3575, SCORES: 0.078489, CLASSES: green
# Time: 0.3924, SCORES: 0.995735, CLASSES: red
# Time: 0.3927, SCORES: 0.998590, CLASSES: red
# Time: 0.3979, SCORES: 0.892268, CLASSES: red
# Time: 0.4322, SCORES: 0.921570, CLASSES: yellow
# Time: 0.3843, SCORES: 0.996859, CLASSES: green
# Time: 0.3732, SCORES: 0.997641, CLASSES: green
# Time: 0.3530, SCORES: 0.999593, CLASSES: red
# Time: 0.5631, SCORES: 0.661113, CLASSES: red
# Time: 0.3686, SCORES: 0.990979, CLASSES: red
# Time: 0.3669, SCORES: 0.998080, CLASSES: green
# Time: 0.3534, SCORES: 0.997878, CLASSES: red
# Time: 0.3698, SCORES: 0.996071, CLASSES: red
# Time: 0.3479, SCORES: 0.998397, CLASSES: green
# Time: 0.4042, SCORES: 0.999614, CLASSES: red
# Time: 0.3824, SCORES: 0.982219, CLASSES: yellow
# Time: 0.3935, SCORES: 0.977332, CLASSES: green
# Time: 0.3696, SCORES: 0.982189, CLASSES: red
# Time: 0.4269, SCORES: 0.999586, CLASSES: red
# Time: 0.4148, SCORES: 0.938915, CLASSES: yellow
# Time: 0.3744, SCORES: 0.994583, CLASSES: red
# Time: 0.3454, SCORES: 0.998515, CLASSES: green
# Time: 0.3532, SCORES: 0.995595, CLASSES: red
# Time: 0.3471, SCORES: 0.933787, CLASSES: yellow
# Time: 0.3501, SCORES: 0.998159, CLASSES: red
# Time: 0.3611, SCORES: 0.996240, CLASSES: yellow
# Time: 0.3532, SCORES: 0.990878, CLASSES: yellow
# Time: 0.3539, SCORES: 0.999672, CLASSES: red
# Time: 0.3612, SCORES: 0.998019, CLASSES: red
# Time: 0.4762, SCORES: 0.999639, CLASSES: red
# Time: 0.3717, SCORES: 0.999310, CLASSES: red
# Time: 0.3821, SCORES: 0.998080, CLASSES: green
# Time: 0.3612, SCORES: 0.993061, CLASSES: green
# Time: 0.3474, SCORES: 0.995849, CLASSES: yellow
# Time: 0.3387, SCORES: 0.998775, CLASSES: red
# Time: 0.4197, SCORES: 0.998643, CLASSES: red
# Time: 0.3449, SCORES: 0.990979, CLASSES: red
# Time: 0.3412, SCORES: 0.976751, CLASSES: yellow
# Time: 0.3737, SCORES: 0.980085, CLASSES: red
# Time: 0.3435, SCORES: 0.982752, CLASSES: yellow
# Time: 0.3882, SCORES: 0.999514, CLASSES: red
# Time: 0.3753, SCORES: 0.997981, CLASSES: green
# Time: 0.3943, SCORES: 0.999464, CLASSES: red
# Time: 0.3948, SCORES: 0.996417, CLASSES: green
# Time: 0.3611, SCORES: 0.994785, CLASSES: green
# Time: 0.4060, SCORES: 0.998760, CLASSES: red
# Time: 0.4244, SCORES: 0.999144, CLASSES: red
# Time: 0.3782, SCORES: 0.948396, CLASSES: red
# Time: 0.3567, SCORES: 0.933787, CLASSES: yellow
# Time: 0.4668, SCORES: 0.995849, CLASSES: yellow
# Time: 0.4041, SCORES: 0.999147, CLASSES: red
# Time: 0.3733, SCORES: 0.998409, CLASSES: green
# Time: 0.3469, SCORES: 0.998535, CLASSES: green
# Time: 0.4380, SCORES: 0.999761, CLASSES: red
# Time: 0.4211, SCORES: 0.357043, CLASSES: red
# Time: 0.3705, SCORES: 0.982219, CLASSES: yellow
# Time: 0.3756, SCORES: 0.995213, CLASSES: red
# Time: 0.4291, SCORES: 0.990615, CLASSES: green
# Time: 0.3686, SCORES: 0.801194, CLASSES: yellow
# Time: 0.3631, SCORES: 0.997933, CLASSES: red
# Time: 0.3544, SCORES: 0.998090, CLASSES: red
# Time: 0.4157, SCORES: 0.995533, CLASSES: red
# Time: 0.3726, SCORES: 0.014728, CLASSES: yellow
# Time: 0.3552, SCORES: 0.999711, CLASSES: red
# Time: 0.3402, SCORES: 0.999789, CLASSES: red
# Time: 0.3603, SCORES: 0.976957, CLASSES: yellow
# Time: 0.3515, SCORES: 0.996776, CLASSES: red
# Time: 0.3648, SCORES: 0.970871, CLASSES: red
# Time: 0.4401, SCORES: 0.578441, CLASSES: yellow
# Time: 0.3839, SCORES: 0.979052, CLASSES: red
# Time: 0.3379, SCORES: 0.995866, CLASSES: yellow
# Time: 0.3428, SCORES: 0.999582, CLASSES: red
# Time: 0.3385, SCORES: 0.561596, CLASSES: red
# Time: 0.3527, SCORES: 0.996168, CLASSES: green
# Time: 0.3977, SCORES: 0.365681, CLASSES: red
# Time: 0.3726, SCORES: 0.999039, CLASSES: red
# Time: 0.3678, SCORES: 0.992441, CLASSES: yellow
# Time: 0.3432, SCORES: 0.995985, CLASSES: green
# Time: 0.3506, SCORES: 0.997527, CLASSES: red
# Time: 0.3583, SCORES: 0.999574, CLASSES: red
# Time: 0.3487, SCORES: 0.956673, CLASSES: red
# Time: 0.4012, SCORES: 0.999514, CLASSES: red
# Time: 0.3640, SCORES: 0.992562, CLASSES: red
# Time: 0.3622, SCORES: 0.160787, CLASSES: red
# Time: 0.3665, SCORES: 0.999645, CLASSES: red
# Time: 0.3508, SCORES: 0.274492, CLASSES: red
# Time: 0.3446, SCORES: 0.882292, CLASSES: red
# Time: 0.3406, SCORES: 0.994595, CLASSES: green
# Time: 0.3489, SCORES: 0.976970, CLASSES: red
# Time: 0.3383, SCORES: 0.995346, CLASSES: red
# Time: 0.3422, SCORES: 0.996515, CLASSES: red
# Time: 0.3375, SCORES: 0.999859, CLASSES: red
# Time: 0.3566, SCORES: 0.999076, CLASSES: red
# Time: 0.3488, SCORES: 0.983685, CLASSES: yellow
# Time: 0.3580, SCORES: 0.503203, CLASSES: red
# Time: 0.4364, SCORES: 0.850795, CLASSES: yellow
# Time: 0.3622, SCORES: 0.999714, CLASSES: red
# Time: 0.3727, SCORES: 0.997341, CLASSES: green
# Time: 0.3410, SCORES: 0.998472, CLASSES: red
# Time: 0.3421, SCORES: 0.985621, CLASSES: red
# Time: 0.3360, SCORES: 0.999001, CLASSES: red
# Time: 0.3369, SCORES: 0.999652, CLASSES: red
# Time: 0.3340, SCORES: 0.998815, CLASSES: red
# Time: 0.3421, SCORES: 0.999717, CLASSES: red
# Time: 0.3311, SCORES: 0.980890, CLASSES: green
# Time: 0.3411, SCORES: 0.999041, CLASSES: green
# Time: 0.3969, SCORES: 0.997588, CLASSES: green
# Time: 0.3689, SCORES: 0.999833, CLASSES: red
# Time: 0.3854, SCORES: 0.997887, CLASSES: green
# Time: 0.3486, SCORES: 0.997495, CLASSES: red
# Time: 0.3781, SCORES: 0.984232, CLASSES: red
# Time: 0.3534, SCORES: 0.274222, CLASSES: red
# Time: 0.3355, SCORES: 0.130799, CLASSES: red
# Time: 0.3410, SCORES: 0.998003, CLASSES: red
# Time: 0.3487, SCORES: 0.835014, CLASSES: yellow
# Time: 0.3416, SCORES: 0.997073, CLASSES: red
# Time: 0.3425, SCORES: 0.999807, CLASSES: red
# Time: 0.3427, SCORES: 0.031659, CLASSES: yellow
# Time: 0.3371, SCORES: 0.975085, CLASSES: red
# Time: 0.3481, SCORES: 0.252060, CLASSES: red
# Time: 0.3494, SCORES: 0.126966, CLASSES: yellow
# Time: 0.3389, SCORES: 0.999361, CLASSES: green
# Time: 0.3981, SCORES: 0.979735, CLASSES: yellow
# Time: 0.3588, SCORES: 0.998515, CLASSES: green
# Time: 0.3380, SCORES: 0.070121, CLASSES: yellow
# Time: 0.3841, SCORES: 0.993693, CLASSES: red
# Time: 0.3527, SCORES: 0.993672, CLASSES: green
# Time: 0.3496, SCORES: 0.979874, CLASSES: red
# Time: 0.3394, SCORES: 0.989520, CLASSES: red
# Time: 0.3602, SCORES: 0.993547, CLASSES: red
# Time: 0.3374, SCORES: 0.084146, CLASSES: yellow
# Time: 0.3409, SCORES: 0.231190, CLASSES: yellow
# Time: 0.3422, SCORES: 0.923400, CLASSES: red
# Time: 0.3585, SCORES: 0.341388, CLASSES: red
# Time: 0.3505, SCORES: 0.033798, CLASSES: yellow
# Time: 0.3481, SCORES: 0.997184, CLASSES: green
# Time: 0.4020, SCORES: 0.999320, CLASSES: red
# Time: 0.3687, SCORES: 0.998204, CLASSES: red
# Time: 0.5892, SCORES: 0.958480, CLASSES: red
# Time: 0.4025, SCORES: 0.991562, CLASSES: red
# Time: 0.3905, SCORES: 0.836895, CLASSES: red
# Time: 0.3603, SCORES: 0.971539, CLASSES: red
# Time: 0.3464, SCORES: 0.084167, CLASSES: yellow
# Time: 0.3396, SCORES: 0.999673, CLASSES: red
# Time: 0.3659, SCORES: 0.062098, CLASSES: yellow
# Time: 0.3440, SCORES: 0.985628, CLASSES: red
# Time: 0.3526, SCORES: 0.989461, CLASSES: red
# Time: 0.3597, SCORES: 0.992505, CLASSES: red
# Time: 0.4255, SCORES: 0.381712, CLASSES: red
# Time: 0.5129, SCORES: 0.999214, CLASSES: green
# Time: 0.4961, SCORES: 0.999894, CLASSES: red
# Time: 0.3886, SCORES: 0.998769, CLASSES: red
# Time: 0.4607, SCORES: 0.827580, CLASSES: red
# Time: 0.3716, SCORES: 0.999761, CLASSES: red
# Time: 0.5069, SCORES: 0.992288, CLASSES: red
# Time: 0.4079, SCORES: 0.265910, CLASSES: red
# Time: 0.3599, SCORES: 0.996442, CLASSES: green
# Time: 0.3517, SCORES: 0.999622, CLASSES: red
# Time: 0.4014, SCORES: 0.259895, CLASSES: red
# Time: 0.3817, SCORES: 0.997443, CLASSES: red
# Time: 0.4102, SCORES: 0.992664, CLASSES: red
# Time: 0.3730, SCORES: 0.992288, CLASSES: red
# Time: 0.3695, SCORES: 0.999761, CLASSES: red
# Time: 0.3813, SCORES: 0.995298, CLASSES: yellow
# Time: 0.3587, SCORES: 0.997981, CLASSES: green
# Time: 0.3929, SCORES: 0.999227, CLASSES: red
# Time: 0.3571, SCORES: 0.988463, CLASSES: red
# Time: 0.3676, SCORES: 0.993567, CLASSES: green
# Time: 0.3601, SCORES: 0.993163, CLASSES: green
# Time: 0.3418, SCORES: 0.999864, CLASSES: red
# Time: 0.3566, SCORES: 0.995808, CLASSES: yellow
# Time: 0.4046, SCORES: 0.860781, CLASSES: red
# Time: 0.3678, SCORES: 0.999131, CLASSES: red
# Time: 0.3691, SCORES: 0.249157, CLASSES: red
# Time: 0.3925, SCORES: 0.998969, CLASSES: green
# Time: 0.3733, SCORES: 0.063190, CLASSES: green
# Time: 0.4065, SCORES: 0.982834, CLASSES: red
# Time: 0.3532, SCORES: 0.985673, CLASSES: red
# Time: 0.3853, SCORES: 0.990996, CLASSES: red
# Time: 0.3598, SCORES: 0.990578, CLASSES: red
# Time: 0.3549, SCORES: 0.997556, CLASSES: red
# Time: 0.3650, SCORES: 0.965366, CLASSES: yellow
# Time: 0.3608, SCORES: 0.741946, CLASSES: red
# Time: 0.3627, SCORES: 0.988932, CLASSES: green
# Time: 0.3765, SCORES: 0.996587, CLASSES: green
# Time: 0.3678, SCORES: 0.984316, CLASSES: red
# Time: 0.3751, SCORES: 0.983649, CLASSES: yellow
# Time: 0.4916, SCORES: 0.995116, CLASSES: red
# Time: 0.3930, SCORES: 0.997837, CLASSES: red
# Time: 0.3840, SCORES: 0.999796, CLASSES: red
# Time: 0.3962, SCORES: 0.995248, CLASSES: red
# Time: 0.3554, SCORES: 0.995808, CLASSES: yellow
# Time: 0.3722, SCORES: 0.998137, CLASSES: red
# Time: 0.3807, SCORES: 0.998273, CLASSES: green
# Time: 0.3676, SCORES: 0.995215, CLASSES: red
# Time: 0.3715, SCORES: 0.996056, CLASSES: red
# Time: 0.3873, SCORES: 0.831370, CLASSES: red
# Time: 0.4486, SCORES: 0.483227, CLASSES: red
# Time: 0.3934, SCORES: 0.999797, CLASSES: red
# Time: 0.6877, SCORES: 0.999625, CLASSES: red
# Time: 0.4073, SCORES: 0.998660, CLASSES: green
# Time: 0.4126, SCORES: 0.948396, CLASSES: red
# Time: 0.4137, SCORES: 0.997588, CLASSES: green
# Time: 0.3514, SCORES: 0.999752, CLASSES: red
# Time: 0.3669, SCORES: 0.999894, CLASSES: red
# Time: 0.3705, SCORES: 0.958480, CLASSES: red
# Time: 0.3619, SCORES: 0.051843, CLASSES: yellow
# Time: 0.3648, SCORES: 0.999668, CLASSES: red
# Time: 0.3674, SCORES: 0.942744, CLASSES: red
# Time: 0.3648, SCORES: 0.147913, CLASSES: green
# Time: 0.3912, SCORES: 0.793563, CLASSES: red
# Time: 0.4421, SCORES: 0.999406, CLASSES: red
# Time: 0.4288, SCORES: 0.993230, CLASSES: green
# Time: 0.4217, SCORES: 0.977048, CLASSES: red
# Total Validation Images : 277, Num correct: 221, Accuracy score: 0.798
